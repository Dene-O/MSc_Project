# %%
from uncertainty_plot import Uncertainty_Plot
import numpy as np

# %%
x = np.arange(100) / 31.42 * 4

# %%
y = np.sin(x)

# %%
uncert = np.ones(100) * 0.2

# %%
y_uncert = np.empty([100,2])
y_uncert[:,0] = y
y_uncert[:,1] = uncert

# %%
Uncertainty_Plot('Title', x, y, uncert, scheme=1)

# %%
Uncertainty_Plot('Title', x, y, uncert, scheme=2)

# %%
Uncertainty_Plot('Title', x, y_uncert, scheme=3)

# %%
Uncertainty_Plot('Title', x, y_uncert, scheme=4)
