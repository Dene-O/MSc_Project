# %%
# Import Libraries
import numpy as np

from project_utils.bb_model         import BB_Model
from project_utils.feature_stats    import Feature_Statistics
from project_utils.feature_stats    import Regression_Container
from project_utils.acq_data_capture import Acq_Data
from project_utils.surroagte_gp     import Surrogate_GP



Num_Points = 1

# %%
# Load Forrester model

Forrester_Data = BB_Model('Forrester')

#Forrester_Data.df().head()
# Out:
# (1000,)
# (1000, 1)

# %%
Forrester_Data.MPL()
# Out:
# C:\Users\deneb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.2967129525278268
# MLPRegressor(random_state=RandomState(MT19937) at 0x136CF399840)

# %%
Forrester_Data.Random_Forest()
# Out:
# 0.9999459076328143
# RandomForestRegressor(random_state=RandomState(MT19937) at 0x136CF399840)

# %%
Forrester_Data.GP()
# Out:
# 0.9946521183464583
# GaussianProcessRegressor()

# %%
print(Forrester_Data.get_features())
# Out:
# ['X']

# %%
#Default settings
from unravel_2.ur_model import UR_Model

X_train, X_test, y_train, y_test = Forrester_Data.get_TT_data()

#Initializing the explainer object
URM_Exp = UR_Model(bbox_model           = Forrester_Data.get_GP(),
                   train_data           = X_train,
                   feature_names        = Forrester_Data.get_features(),
                   categorical_features = Forrester_Data.get_catagorical(),
                   mode                 = Forrester_Data.get_mode(),
                   sampling_optimize    = "opt")

#sur_GP = Surrogate_GP()

# %%
mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)
print('Mean 0:', mean)
print('Std 0: ', std)
# Out:
# Mean 0: [0.49681875]
# Std 0:  [0.2894809]

# %%
# Generate explantion data for Random Forest

Forrester_Stats = Feature_Statistics(feature_names = Forrester_Data.get_features(), mode = Forrester_Data.get_mode())

if Num_Points == 0: Num_Points = X_test.shape[0]

for test_instance in range(Num_Points):

    print('INSTANCE: ', test_instance)
       
#    data_row  = np.array([X_test[test_instance]])
    data_row  = np.array([0.4])
    print('data row ',data_row)
    
    #scores, acq_data = URM_Exp.explain(X_init            = data_row.reshape(1, -1),
    scores = URM_Exp.explain(X_init      = data_row.reshape(-1, 1),
                             kernel_type = "Matern",
                             max_iter    = 20,
                             alpha       = "FUR_W",
                             #jitter=5,
                             interval    = 1,
                             normalize   = False)
       
    f_predict = Forrester_Data.get_Random_Forest().predict(data_row.reshape(1, -1))

    e_predict = URM_Exp.exp_predict(data_row.reshape(-1, 1))
    e_predict = np.array(e_predict).ravel()
    
    acq_data = URM_Exp.get_acq_data()
    
#    X, y = URM_Exp.get_surrogate_data()

#    e_predict = sur_GP.predict(X, y)
#    e_predict = sur_GP.predict(URM_Exp.get_surrogate_data())

    print(f_predict, e_predict)
    
    Forrester_Stats.Add_Sample(sample_scores = scores,
                               outcome       = y_test[test_instance],
                               X_row         = data_row,
                               f_prediction  = f_predict,
                               e_prediction  = e_predict.ravel(),
                               feopt         = acq_data.get_fe_x0(),
                               model         = URM_Exp.get_exp_model())
# Out:
# INSTANCE:  0
# data row  [0.4]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.174070476771965
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([0.07494216])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 4
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([0.1105191])
# NEXT X:  [[0.1105191]]
# C:\Users\deneb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.4999999971059707
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.07880586])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 108
#       nit: 6
#      njev: 54
#    status: 0
#   success: True
#         x: array([0.11511692])
# NEXT X:  [[0.11511692]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.2912657071071899
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.16408832])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 4
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([0.6894809])
# NEXT X:  [[0.6894809]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.39165282016397024
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([6.62248031e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 14
#       nit: 2
#      njev: 7
#    status: 0
#   success: True
#         x: array([0.52789623])
# NEXT X:  [[0.52789623]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.4533132052387283
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.79931675e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 24
#       nit: 4
#      njev: 12
#    status: 0
#   success: True
#         x: array([0.22508301])
# NEXT X:  [[0.22508301]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.4036178435421053
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([6.75570711e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 16
#       nit: 3
#      njev: 8
#    status: 0
#   success: True
#         x: array([0.30604316])
# NEXT X:  [[0.30604316]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.2045477941527279
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([7.77156118e-08])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 18
#       nit: 2
#      njev: 9
#    status: 0
#   success: True
#         x: array([0.26374088])
# NEXT X:  [[0.26374088]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.20232967739894417
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([8.32667269e-09])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 20
#       nit: 4
#      njev: 10
#    status: 0
#   success: True
#         x: array([0.35192489])
# NEXT X:  [[0.35192489]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.05733553041991643
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.91433544e-08])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 20
#       nit: 3
#      njev: 10
#    status: 0
#   success: True
#         x: array([0.33095214])
# NEXT X:  [[0.33095214]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.03451778363694979
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-5.2652327e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 24
#       nit: 3
#      njev: 12
#    status: 0
#   success: True
#         x: array([0.28651901])
# NEXT X:  [[0.28651901]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.18596040691309226
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([6.34770015e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 3
#      njev: 6
#    status: 0
#   success: True
#         x: array([0.46152578])
# NEXT X:  [[0.46152578]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.06528085215557818
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([7.14150961e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 16
#       nit: 3
#      njev: 8
#    status: 0
#   success: True
#         x: array([0.43444589])
# NEXT X:  [[0.43444589]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.16293902153474404
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.38777877e-08])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 18
#       nit: 3
#      njev: 9
#    status: 0
#   success: True
#         x: array([0.60465026])
# NEXT X:  [[0.60465026]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.023465123886276647
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.96557787e-07])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 14
#       nit: 3
#      njev: 7
#    status: 0
#   success: True
#         x: array([0.41927016])
# NEXT X:  [[0.41927016]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.009104324554009693
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([2.87270208e-07])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 18
#       nit: 3
#      njev: 9
#    status: 0
#   success: True
#         x: array([0.44647623])
# NEXT X:  [[0.44647623]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.0017114532459567263
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([9.71792092e-07])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 18
#       nit: 5
#      njev: 9
#    status: 0
#   success: True
#         x: array([0.45263439])
# NEXT X:  [[0.45263439]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.018006607779064814
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.49400542e-08])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 16
#       nit: 5
#      njev: 8
#    status: 0
#   success: True
#         x: array([0.49310431])
# NEXT X:  [[0.49310431]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: 0.004504890758927944
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([3.08780779e-08])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 16
#       nit: 4
#      njev: 8
#    status: 0
#   success: True
#         x: array([0.41157305])
# NEXT X:  [[0.41157305]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.010736331545367312
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([6.93889391e-08])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 3
#      njev: 6
#    status: 0
#   success: True
#         x: array([0.48153191])
# NEXT X:  [[0.48153191]]
# Bounds:  Bounds(array([0.1105191]), array([0.6894809]))
#       fun: -0.007213338089968371
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-9.21988181e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 3
#      njev: 6
#    status: 0
#   success: True
#         x: array([0.3442655])
# NEXT X:  [[0.3442655]]
# [0.11505352] [4.54879761e-01 1.00000004e-05]

# %%
import matplotlib.pyplot as plt

# %%
print(f_predict)
print(e_predict)
# Out:
# [0.11505352]
# [4.54879761e-01 1.00000004e-05]

# %%
Forrester_Stats.Fidelity()
# Out:
# Average, Var, and Max Differences:
# y - BB(x):           0.8504539371428759  :  0.0  :  0.8504539371428759
# y - exp(x):          0.5106276931402987  :  0.0  :  0.5106276931402987
# BB(x) - exp(x):      0.3398262440025772  :  0.0  :  0.3398262440025772
# Average exp(x) var:  1.0000000413701846e-05

# %%
#Forrester_Stats.Jaccard_Values()

# %%
Forrester_Stats.Reg_Fidelity_Graph()

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern
from sklearn.gaussian_process.kernels import RBF

#X, y = URM_Exp.get_surrogate_data()
#kernel = Matern()

#GP = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer = 10, optimizer='fmin_l_bfgs_b', normalize_y = False, copy_X_train=True)
#GP.fit(X, y)
        
#print(y[0])
#fe = GP.predict(X[0].reshape(1,-1))
#print(fe)
#ey = URM_Exp.gpmodel_predict(X[0].reshape(1,-1))
#print(ey)

# %%
acq_data.plot_point()

# %%
acq_data.plot_point(1)

# %%
acq_data.plot_point(2)

# %%
acq_data.plot_point(3)

# %%
acq_data.plot_point(4)

# %%
acq_data.plot_point(5)

# %%
acq_data.plot_point(6)

# %%
acq_data.plot_point(7)

# %%
acq_data.plot_point(8)

# %%
acq_data.plot_point(9)

# %%
acq_data.plot_point(10)

# %%
acq_data.plot_point(11)

# %%
acq_data.plot_point(12)

# %%
acq_data.plot_point(13)

# %%
acq_data.plot_point(14)

# %%
acq_data.plot_point(15)

# %%
acq_data.plot_point(16)

# %%
acq_data.plot_point(17)

# %%
acq_data.plot_point(18)

# %%
acq_data.plot_point(19)

# %%
acq_data.plot_all()
