# %% [markdown]
# ## Read a data Stats Object from a File

# %%
from project_utils.feature_stats import Feature_Statistics

# %%
file_handle = open('results_dir\\test.res', 'rb')

# %%
fs = Feature_Statistics(file_handle=file_handle)

# %%
file_handle.close()

# %%
fs.Feature_Counts(max_features=8, scaled=True, threshold=0.075)

# %%
fs.Frequency_Plot()

# %%
fs.Frequency_Plot(top_features=False, display_feature_list=True)
# Out:
# 1 -      Active_1
# 2 -      Active_2
# 3 -      Active_3
# 4 -      Active_4
# 5 -      Active_5
# 6 -      Passive_1
# 7 -      Passive_2
# 8 -      Passive_3
# 9 -      Passive_4
# 10 -     Passive_5

# %%
fs.Box_Plot()
# Out:
# 1 -      Active_1
# 2 -      Active_2
# 3 -      Active_3
# 4 -      Active_4
# 5 -      Active_5
# 6 -      Passive_2
# 7 -      Passive_3
# 8 -      Passive_5

# %%
fs.Violin_Plot(top_features=False)
# Out:
# 1 -      Active_1
# 2 -      Active_2
# 3 -      Active_3
# 4 -      Active_4
# 5 -      Active_5
# 6 -      Passive_1
# 7 -      Passive_2
# 8 -      Passive_3
# 9 -      Passive_4
# 10 -     Passive_5

# %%
fs.View_Explanation(instance=99)
